# %% [markdown]
# # <font color="#0F0B0B">PS4 Video Games Sales Dataset</font>

# %% [markdown]
# ## <font color="#86BC24">Data Analysis and Visualization of various PS4 video games</font>

# %% [markdown]
# ### [_Dataset Link_ ](https://www.kaggle.com/sidtwr/videogames-sales-dataset?select=PS4_GamesSales.csv)
#
# <br>
#
# >_There are 3 datasets in this link. My dataset is_ `PS4_GamesSales.csv`
# <br><br>
# >**This dataset consists of attributes like- Game, Year, Genre, Publisher, and sales in different regions**

# %% [markdown]
# ### What we will be doing:
# >**Data Analysis:** _Looking at the data to figure out what is the data about._
# <br>
# >**Data Cleaning:** _Check for the missing or null values and remove irrelevent data if required._
# <br>
# >**Data Visualization:** _The data will be observed visually by plotting some graphs and search for any trends, relations & correlations._
# <br>

# %% [markdown]
# ### <font color="purple">DATA ANALYSIS _(analyse and understand the data)_ </font>

# %% [markdown]
# **_Importing some required libraries_**

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# **_Reading the dataset csv file and displaying the data_**

# %%
df = pd.read_csv("PS4_GamesSales.csv", index_col=0, encoding = "ISO-8859-1")
data = df.copy()
data
# Out:
#                                       Year             Genre       Publisher  \
# Game
# Grand Theft Auto V                  2014.0            Action  Rockstar Games
# Call of Duty: Black Ops 3           2015.0           Shooter      Activision
# Red Dead Redemption 2               2018.0  Action-Adventure  Rockstar Games
# Call of Duty: WWII                  2017.0           Shooter      Activision
# FIFA 18                             2017.0            Sports       EA Sports
# ...                                    ...               ...             ...
# Fallen Legion: Flames of Rebellion     NaN      Role-Playing             NaN
# Radial G Racing Revolved            2017.0            Racing   Tammeka Games
# The Mummy Demastered                   NaN            Action             NaN
# Project Nimbus: Code Mirai             NaN            Action             NaN
# Battle Chef Brigade                    NaN            Action             NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1034 entries, Grand Theft Auto V to Battle Chef Brigade
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           825 non-null    float64
#  1   Genre          1034 non-null   object
#  2   Publisher      825 non-null    object
#  3   North America  1034 non-null   float64
#  4   Europe         1034 non-null   float64
#  5   Japan          1034 non-null   float64
#  6   Rest of World  1034 non-null   float64
#  7   Global         1034 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 72.7+ KB

# %% [markdown]
# >**<font color="teal">About the dataset</font>**<br><br>
# >This dataset has 8 columns displayed above.<br>
# >There are total 1034 entries in the dataset.<br>
# >The memory used is 72.7 KB.
# <br><br>
# >The datatype of each column is also displayed.
# <br><br>

# %%
data.shape
# Out:
# (1034, 8)

# %% [markdown]
# >**<font color="teal">Dimensions of Data</font>**<br><br>
# >This again shows that the dataset has 1034 rows and 8 columns
# <br><br>

# %%
data.describe()
# Out:
#               Year  North America       Europe        Japan  Rest of World  \
# count   825.000000    1034.000000  1034.000000  1034.000000    1034.000000
# mean   2015.966061       0.204613     0.248714     0.033636       0.089014
# std       1.298360       0.563471     0.785491     0.108344       0.249410
# min    2013.000000       0.000000     0.000000     0.000000       0.000000
# 25%    2015.000000       0.000000     0.000000     0.000000       0.000000
# 50%    2016.000000       0.020000     0.000000     0.000000       0.010000
# 75%    2017.000000       0.120000     0.130000     0.030000       0.050000
# max    2020.000000       6.180000     9.710000     2.170000       3.020000
#
#             Global
# count  1034.000000
# mean      0.576054
# std       1.583534
# min       0.000000
# 25%       0.000000
# 50%       0.060000
# 75%       0.357500
# max      19.390000

# %% [markdown]
# >**<font color="teal">About the data</font>**<br><br>
# >There are 825 rows in `Year` but 1034 rows in many other columns like `North America`.<br><br>
# >This means there might be some _undefined_ or _null_ values in `Year`.<br><br>
# >Also the Video Games are published in between **2013** to **2020** as you can see in `min` and `max` in `Year` column.
# <br><br>

# %% [markdown]
# **_Number of unique data in dataset for each column_**

# %%
data.nunique()
# Out:
# Year               8
# Genre             17
# Publisher        152
# North America    129
# Europe           139
# Japan             45
# Rest of World     85
# Global           206
# dtype: int64

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### <font color="purple">DATA CLEANING </font>

# %% [markdown]
# **_Number of null values in the dataset for every column_**

# %%
data.isna().sum()
# Out:
# Year             209
# Genre              0
# Publisher        209
# North America      0
# Europe             0
# Japan              0
# Rest of World      0
# Global             0
# dtype: int64

# %% [markdown]
# >**<font color="teal">_null_ values</font>**<br><br>
# >There are 209 _null_ values in `Year` and `Publisher`.<br><br>
# >We can see that no other columns have a single _null_ value
# >Also we can easily see from the query below that all the 209 _null_ values of both the columns are same and we need to remove those 209 values only.
# <br><br>

# %%
data[data['Year'].isna()]
# Out:
#                                     Year         Genre Publisher  \
# Game
# Ultra Street Fighter IV              NaN      Fighting       NaN
# Dragon's Dogma Online                NaN  Role-Playing       NaN
# This War of Mine                     NaN        Action       NaN
# A Boy and His Blob                   NaN      Platform       NaN
# Another World                        NaN     Adventure       NaN
# ...                                  ...           ...       ...
# Sakuna: Of Rice and Ruin             NaN        Action       NaN
# Fallen Legion: Flames of Rebellion   NaN  Role-Playing       NaN
# The Mummy Demastered                 NaN        Action       NaN
# Project Nimbus: Code Mirai           NaN        Action       NaN
# Battle Chef Brigade                  NaN        Action       NaN
#
#                                     North America  Europe  Japan  \
# Game
# Ultra Street Fighter IV                       0.0    0.08   0.00
# ...

# %% [markdown]
# >**<font color="teal">_null_ values</font>**<br><br>
# >We can see that the rows having _NaN_ in `Year` has also _NaN_ in `Publisher`.<br><br>
# >So just eliminate these rows, only if there is a need of data where `Year` or `Publisher` is needed.
# >Else, we can use the data without removing _NaN_ or _null_ values.
# <br><br>

# %% [markdown]
# **_Making a new dataframe for data without null values_**

# %%
dataWOna = data[data['Year'].notna()]
print(len(dataWOna), len(data))
dataWOna.reset_index(inplace=True)
print(dataWOna.isna().sum())
dataWOna
# Out:
# 825 1034
# Game             0
# Year             0
# Genre            0
# Publisher        0
# North America    0
# Europe           0
# Japan            0
# Rest of World    0
# Global           0
# dtype: int64
#                           Game    Year             Genre  \
# 0           Grand Theft Auto V  2014.0            Action
# 1    Call of Duty: Black Ops 3  2015.0           Shooter
# 2        Red Dead Redemption 2  2018.0  Action-Adventure
# 3           Call of Duty: WWII  2017.0           Shooter
# 4                      FIFA 18  2017.0            Sports
# ..                         ...     ...               ...
# 820                  Biomutant  2019.0            Action
# 821                    de Blob  2017.0          Platform
# 822           Chaos on Deponia  2017.0         Adventure
# 823                  Code Vein  2018.0            Action
# 824   Radial G Racing Revolved  2017.0            Racing
#
# ...

# %% [markdown]
# >**<font color="teal">Removing _null_ values</font>**<br><br>
# >On removing all _null_ values we can see that the length of the dataset decreased from **1034** to **825**.<br><br>
# >No column now has a _null_ value.
# <br><br>

# %% [markdown]
# > Now, the data has no _null_ values or any shoddy values.

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### <font color="purple">DATA VISUALISATION</font>

# %% [markdown]
# ### **_Total number of games published each year_**

# %%
years = np.sort(dataWOna['Year'].unique())
gamesEachYr = (dataWOna.groupby('Year').count())['Game'].to_numpy()
print(years, gamesEachYr)
# Out:
# [2013. 2014. 2015. 2016. 2017. 2018. 2019. 2020.] [ 20  98 172 222 254  39  12   8]

# %% [markdown]
# >We now have 2 numpy arrays for _years_ and _number of games each year_.
# <br><br>

# %% [markdown]
# **_Line Plot_**

# %%
plt.figure(figsize=(10, 6))

plt.plot(years, gamesEachYr, color='red', linewidth=2, marker='o')
plt.title("Number of Games for PS4 each Year (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.xlabel("Years", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Number of Games", fontdict = {'fontsize': 15}, labelpad=30)

plt.grid(linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# **_Bar Plot_**

# %%
plt.figure(figsize=(10, 6))

bars = plt.bar(years, gamesEachYr, color=['lightblue', 'cyan', 'orange', 'red', 'red', 'green', 'lightgreen', 'lightgreen'], edgecolor="black")
plt.title("Number of Games for PS4 each Year (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.xlabel("Years", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Number of Games", fontdict = {'fontsize': 15}, labelpad=30)

plt.grid(linestyle="--", alpha=0.3)
plt.show()

# %% [markdown]
# >From both the graphs, we can come to the point that **maximum number of games were released in 2017**.<br><br>
# >Also **after 2017, the total number of games substantially decreased**.
# <br><br>

# %% [markdown]
# ### **_Top 10 publishers with Maximum Games published_**

# %%
publisher_data = (dataWOna.groupby('Publisher').count().sort_values('Game', ascending=False))['Game'].to_frame()
publisher_data.reset_index(inplace=True)
publisher_data.head(10)
# Out:
#                                 Publisher  Game
# 0                      Namco Bandai Games    56
# 1          Sony Interactive Entertainment    47
# 2                                 Ubisoft    45
# 3                             Square Enix    40
# 4                              Tecmo Koei    37
# 5                              Activision    30
# 6                                  Capcom    30
# 7  Warner Bros. Interactive Entertainment    27
# 8             Sony Computer Entertainment    25
# 9                             NIS America    21

# %% [markdown]
# >Created a new dataframe having _publishers_ and their _number of games published_.
# <br>

# %%
publishers = publisher_data.head(10)['Publisher'].to_numpy()
games = publisher_data.head(10)['Game'].to_numpy()

# %% [markdown]
# **_Horizontal Bar Plot_**

# %%
plt.figure(figsize=(10, 6))

plt.barh(publishers, games, color=['red', 'orange', 'orange', 'lightblue', 'lightblue', 'cyan', 'cyan', 'teal', 'lightgreen', 'lightgreen'], edgecolor="black")
plt.title("Top 10 Publishers with highest \"Total Games published\" (2013-2020)", y=1.05, fontdict = {'fontsize': 20, 'color': 'blue'})
plt.gca().invert_yaxis()

plt.xlabel("Number of Games", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Publishers", fontdict = {'fontsize': 15}, labelpad=20)

plt.grid(linestyle="--", alpha=0.3)
plt.plot()
# Out:
# []

# %% [markdown]
# > We can see by the above graph that **Namco Bandai Games** has highest number of games published till now.<br>
# >Followed by **Sony Interactive Entertainment** and **Ubisoft**
# <br>

# %% [markdown]
# ### **_Top 10 publishers with Maximum Global Sales_**

# %%
publishers_Gsales = (dataWOna.groupby('Publisher').sum().sort_values('Global', ascending=False))['Global'].to_frame()
publishers_Gsales.reset_index(inplace=True)
publishers_Gsales.head(10)
# Out:
#                                 Publisher  Global
# 0                              Activision   72.44
# 1                                 Ubisoft   59.16
# 2                         Electronic Arts   54.96
# 3          Sony Interactive Entertainment   54.85
# 4                               EA Sports   47.55
# 5             Sony Computer Entertainment   42.26
# 6                          Rockstar Games   33.93
# 7                             Square Enix   29.92
# 8                      Bethesda Softworks   28.96
# 9  Warner Bros. Interactive Entertainment   27.83

# %% [markdown]
# >Created a new dataframe having _publishers_ and their _total global sales_.
# <br>

# %%
publishers = publishers_Gsales.head(10)['Publisher'].to_numpy()
global_revenue = publishers_Gsales.head(10)['Global'].to_numpy()

# %% [markdown]
# **_Horizontal Bar Plot_**

# %%
plt.figure(figsize=(10, 6))

plt.barh(publishers, global_revenue, color=['red', 'orange', 'orange', 'orange', 'lightblue', 'cyan', 'teal', 'lightgreen', 'lightgreen', 'lightgreen'], edgecolor="black")
plt.title("Top 10 Publishers with highest \"Global Sales\" (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.gca().invert_yaxis()

plt.xlabel("Total Global Sales", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Publishers", fontdict = {'fontsize': 15}, labelpad=15)

plt.grid(linestyle="--", alpha=0.3)
plt.plot()
# Out:
# []

# %% [markdown]
# > We can see by the above graph that **Activision** has highest Global Sales till now.<br>
# >Followed by **Ubisoft** and **Electronic Arts**
# <br>

# %% [markdown]
# ### **_Top 10 publishers with Maximum Global Sales PER GAME_**

# %%
publishers_Gsales_t10 = publishers_Gsales.copy()

total_games = []
gsales_per_game = []
for i in range(len(publishers_Gsales_t10)):
    pub = publishers_Gsales_t10['Publisher'].iloc[i]
    tot = publisher_data[publisher_data['Publisher']==pub]['Game'].iloc[0]
    total_games.append(tot)
    gsales_per_game.append(publishers_Gsales_t10['Global'].iloc[i]/tot)


publishers_Gsales_t10['Total Games'] = total_games
publishers_Gsales_t10['G-Sales per Game'] = gsales_per_game
publishers_Gsales_t10.sort_values('G-Sales per Game', ascending=False, inplace=True)
publishers_Gsales_t10.head(10)
# Out:
#                       Publisher  Global  Total Games  G-Sales per Game
# 6                Rockstar Games   33.93            3         11.310000
# 15       Blizzard Entertainment    7.36            2          3.680000
# 16     Warner Bros. Interactive    6.56            2          3.280000
# 2               Electronic Arts   54.96           21          2.617143
# 4                     EA Sports   47.55           19          2.502632
# 11                    2K Sports   17.36            7          2.480000
# 0                    Activision   72.44           30          2.414667
# 24                  Hello Games    2.26            1          2.260000
# 8            Bethesda Softworks   28.96           17          1.703529
# 5   Sony Computer Entertainment   42.26           25          1.690400

# %% [markdown]
# >Created a new dataframe having _publishers_ and their _global sales per game_ with other attributes.
# <br>

# %%
publishers = publishers_Gsales_t10.head(10)['Publisher'].to_numpy()
gsales_pgame = publishers_Gsales_t10.head(10)['G-Sales per Game'].to_numpy()

# %% [markdown]
# **_Horizontal Bar Plot_**

# %%
plt.figure(figsize=(10, 6))

bars = plt.barh(publishers, gsales_pgame, color=['red', 'orange', 'orange', 'green', 'green', 'green', 'lightgreen', 'lightgreen', 'cyan', 'cyan'], edgecolor="black")
plt.title("Top 10 Publishers with highest \"Global Sales Per Game\" (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.gca().invert_yaxis()

plt.xlabel("Global Sales Per Game", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Publishers", fontdict = {'fontsize': 15}, labelpad=15)

plt.grid(linestyle="--", alpha=0.3)
plt.plot()
# Out:
# []

# %% [markdown]
# > We can see by the above graph that **Rockstar Games** has significant high Global Sales Per Game till now.<br>
# >Followed by **Blizzard Entertainment** and **Warner Bros. Interactive**
# <br>

# %% [markdown]
# ### **_Total Games released by "Activision" every year_**

# %%
activisionGames_eachYear = dataWOna[dataWOna['Publisher']=='Activision'].groupby('Year').count()['Game'].to_frame()
activisionGames_eachYear.reset_index(inplace=True)
activisionGames_eachYear
# Out:
#      Year  Game
# 0  2013.0     3
# 1  2014.0     7
# 2  2015.0     8
# 3  2016.0     8
# 4  2017.0     4

# %% [markdown]
# >Created a new dataframe having _years_ and their _total games each year_.
# <br>

# %%
years = activisionGames_eachYear['Year'].to_numpy()
games = activisionGames_eachYear['Game'].to_numpy()

# %% [markdown]
# **_Line Plot_**

# %%
plt.figure(figsize=(10, 6))

plt.plot(years, games, color='green', linewidth=2, marker='o')
plt.title("Total Games published by Activision each Year (2013-2017)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.xlabel("Years", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Total Games published", fontdict = {'fontsize': 15}, labelpad=30)
plt.xticks(years)

plt.grid(linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# > We can see by the above graph that **8 games** were published by Activision in **2015** and **2016** and were the **most games published in a single year**.<br>
# <br>

# %% [markdown]
# ### **_Total Global Sales by "Activision" every year_**

# %%
activisionGsales_eachYear = dataWOna[dataWOna['Publisher']=='Activision'].groupby('Year').sum()['Global'].to_frame()
activisionGsales_eachYear.reset_index(inplace=True)
activisionGsales_eachYear
# Out:
#      Year  Global
# 0  2013.0    4.84
# 1  2014.0   14.60
# 2  2015.0   19.90
# 3  2016.0   10.15
# 4  2017.0   22.95

# %% [markdown]
# >Created a new dataframe having _years_ and their _total global sales each year_.
# <br>

# %%
years = activisionGsales_eachYear['Year'].to_numpy()
gsales = activisionGsales_eachYear['Global'].to_numpy()

# %% [markdown]
# **_Line Plot_**

# %%
plt.figure(figsize=(10, 6))

plt.plot(years, gsales, color='purple', linewidth=3, marker='o')
plt.title("Global Sales by Activision each Year (2013-2017)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.xlabel("Years", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Global Sales", fontdict = {'fontsize': 15}, labelpad=30)
plt.xticks(years)

plt.grid(linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# > We can see by the above graph that Global Sales by Activision were **highest in 2017** and was the **least in 2013**<br>
# <br>

# %% [markdown]
# ### **_Number of Games in every Genre_**

# %%
genre_data = data.groupby("Genre").count()
genre_data = genre_data.rename(columns = {'Year': 'Games'})['Games'].to_frame()
genre_data.reset_index(inplace=True)
genre_data
# Out:
#                Genre  Games
# 0             Action    205
# 1   Action-Adventure     38
# 2          Adventure     71
# 3           Fighting     32
# 4                MMO      8
# 5               Misc     55
# 6              Music     18
# 7              Party      2
# 8           Platform     33
# 9             Puzzle     10
# 10            Racing     48
# 11      Role-Playing    107
# 12           Shooter     75
# 13        Simulation     21
# 14            Sports     69
# 15          Strategy     25
# 16      Visual Novel      8

# %% [markdown]
# >Created a new dataframe having all _genre_ and _total games made in that genre_.
# <br>

# %%
genre = genre_data['Genre']
num_games = genre_data['Games']

# %% [markdown]
# **_Bar Plot_**

# %%
plt.figure(figsize=(10, 6))

bars = plt.bar(genre, num_games, color=(0.9, 0.9, 0.9, 1), edgecolor='red', linewidth=2)
plt.title("Number of Games in each Genre (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.xticks(genre, rotation=75)

plt.xlabel("Genre", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Number of Games", fontdict = {'fontsize': 15}, labelpad=30)

plt.plot()
# Out:
# []

# %% [markdown]
# > We can see by the above graph that **Action** genre has the highest number of games published.<br>
# > While **Party** based games are the least published.
# <br>

# %% [markdown]
# ### **_Checking Sales in All Regions and Comparing them_**

# %%
sales_data = dataWOna.groupby('Year').sum()
sales_data = sales_data[sales_data['Global']!=0.00]
sales_data.reset_index(inplace=True)
sales_data
# Out:
#      Year  North America  Europe  Japan  Rest of World  Global
# 0  2013.0          10.35   12.88   0.97           4.57   28.76
# 1  2014.0          39.80   54.12   3.58          18.29  115.85
# 2  2015.0          49.60   56.21   7.28          20.88  133.99
# 3  2016.0          47.40   57.98   9.65          20.71  135.72
# 4  2017.0          44.77   57.18   9.08          19.89  130.90
# 5  2018.0          19.65   18.70   4.13           7.69   50.20

# %% [markdown]
# >Created a new dataframe having _years_ and  all the _sales in all regions_.
# <br>

# %%
na_sales = sales_data['North America']
eu_sales = sales_data['Europe']
jp_sales = sales_data['Japan']
rst_sales = sales_data['Rest of World']
glb_sales = sales_data['Global']

years = sales_data['Year']

# %%
plt.figure(figsize=(14, 8))

plt.plot(years, na_sales, color='orange', linewidth=3, label='North America')
plt.plot(years, eu_sales, color='blue', linewidth=3, label='Europe')
plt.plot(years, jp_sales, color='green', linewidth=3, label='Japan')
plt.plot(years, rst_sales, color='violet', linewidth=3, label='Rest of World')
plt.plot(years, glb_sales, color='black', linewidth=3, label='Global')


plt.title("Region based Sales comparision each Year (2013-2018)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.xlabel("Years", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Sales", fontdict = {'fontsize': 15}, labelpad=30)
plt.legend()
plt.xticks(years)

plt.show()

# %% [markdown]
# > We can see by the above graph that **Europe** is the biggest market for games over the years as it always has the highest sales as compared to other regions.<br>
# >Also, **North America** is the second biggest market for games.
# <br>

# %% [markdown]
# ### **_Correlation between different attributes of the dataset_**

# %%
corr_data = data.copy()
corr_data.drop('Year', axis=1, inplace=True)
corr_data = corr_data[corr_data['Global']!=0.00]
corr_mat = corr_data.corr()
corr_mat
# Out:
#                North America    Europe     Japan  Rest of World    Global
# North America       1.000000  0.806333  0.374631       0.950307  0.934559
# Europe              0.806333  1.000000  0.346249       0.950304  0.960607
# Japan               0.374631  0.346249  1.000000       0.379437  0.435107
# Rest of World       0.950307  0.950304  0.379437       1.000000  0.997059
# Global              0.934559  0.960607  0.435107       0.997059  1.000000

# %% [markdown]
# >**Correlation table to be converted to heatmap**

# %% [markdown]
# **_Heat Map_**

# %%
plt.figure(figsize=(10, 6))

plt.title("Correlation matrix for Sales across all Regions", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.rc('font', size=12)

sns.heatmap(corr_mat, cmap ="icefire", linewidths = 0.1, annot=True)

# %% [markdown]
# > We can see by the above graph that **Europe** and **Global** sales have highest correlation.<br>
# > And **Japan** and **Europe** sales have least correlation.
# <br>

# %% [markdown]
# ### **_Global Sales in each Genre_**

# %%
genre_sales = data.groupby("Genre").sum()['Global'].to_frame()
genre_sales.reset_index(inplace=True)
genre_sales
# Out:
#                Genre  Global
# 0             Action  136.85
# 1   Action-Adventure   61.86
# 2          Adventure   15.22
# 3           Fighting   19.46
# 4                MMO    3.52
# 5               Misc   12.47
# 6              Music    5.03
# 7              Party    0.65
# 8           Platform   17.85
# 9             Puzzle    0.52
# 10            Racing   25.29
# 11      Role-Playing   62.82
# 12           Shooter  134.99
# 13        Simulation    4.52
# 14            Sports   92.85
# 15          Strategy    1.28
# 16      Visual Novel    0.46

# %% [markdown]
# >Created a new dataframe having all _genre_ and _global sales in that genre_.
# <br>

# %%
genre = genre_sales['Genre']
glb_sales = genre_sales['Global']

# %% [markdown]
# **_Line Plot over Bar Plot_**

# %%
plt.figure(figsize=(14, 8))

glb_sales.plot(color='purple', grid=True, label='Global Sales', linewidth=3)
sns.barplot(genre, glb_sales, alpha=0.8, edgecolor='black').set_xticklabels(genre, rotation=75, horizontalalignment='right')

plt.title("Global Sales in each Genre (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.ylabel("Global Sales", fontdict = {'fontsize': 15}, labelpad=20)
plt.xlabel("Genre", fontdict = {'fontsize': 15})
plt.legend()
plt.show()

# %% [markdown]
# > We can see by the above graph that globally, **Action** is the most popular genre closely followed by **Shooter** games.
# <br>

# %% [markdown]
# ### **_North America Sales in each Genre_**

# %%
genre_nasales = data.groupby("Genre").sum()['North America'].to_frame()
genre_nasales.reset_index(inplace=True)
genre_nasales
# Out:
#                Genre  North America
# 0             Action          48.15
# 1   Action-Adventure          22.30
# 2          Adventure           5.27
# 3           Fighting           8.58
# 4                MMO           1.32
# 5               Misc           3.64
# 6              Music           2.40
# 7              Party           0.09
# 8           Platform           5.48
# 9             Puzzle           0.28
# 10            Racing           5.86
# 11      Role-Playing          22.15
# 12           Shooter          50.50
# 13        Simulation           1.47
# 14            Sports          33.31
# 15          Strategy           0.57
# 16      Visual Novel           0.20

# %%
genre = genre_nasales['Genre']
na_sales = genre_nasales['North America']

# %% [markdown]
# **_Line Plot over Bar Plot_**

# %%
plt.figure(figsize=(14, 8))

na_sales.plot(color='purple', grid=True, label='North America Sales', linewidth=3)
sns.barplot(genre, na_sales, alpha=0.8, edgecolor='black').set_xticklabels(genre, rotation=75, horizontalalignment='right')

plt.title("North America Sales in each Genre (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.ylabel("North America Sales", fontdict = {'fontsize': 15})
plt.xlabel("Genre", fontdict = {'fontsize': 15}, labelpad=20)
plt.legend()
plt.show()

# %% [markdown]
# > We can see by the above graph that in North America, **Shooter** surpasses **Action** games as the most popular genre, unlike the global situation.
# <br>

# %% [markdown]
# ### **_Europe Sales in each Genre_**

# %%
genre_eusales = data.groupby("Genre").sum()['Europe'].to_frame()
genre_eusales.reset_index(inplace=True)
genre_eusales
# Out:
#                Genre  Europe
# 0             Action   57.53
# 1   Action-Adventure   27.79
# 2          Adventure    6.08
# 3           Fighting    6.19
# 4                MMO    1.45
# 5               Misc    6.03
# 6              Music    1.62
# 7              Party    0.47
# 8           Platform    8.92
# 9             Puzzle    0.16
# 10            Racing   14.77
# 11      Role-Playing   22.40
# 12           Shooter   58.64
# 13        Simulation    2.07
# 14            Sports   42.81
# 15          Strategy    0.22
# 16      Visual Novel    0.02

# %%
genre = genre_eusales['Genre']
eu_sales = genre_eusales['Europe']

# %% [markdown]
# **_Line Plot over Bar Plot_**

# %%
plt.figure(figsize=(14, 8))

eu_sales.plot(color='purple', grid=True, label='Europe Sales', linewidth=3)
sns.barplot(genre, eu_sales, alpha=0.8, edgecolor='black').set_xticklabels(genre, rotation=75, horizontalalignment='right')

plt.title("Europe Sales in each Genre (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.ylabel("Europe Sales", fontdict = {'fontsize': 15}, labelpad=20)
plt.xlabel("Genre", fontdict = {'fontsize': 15})
plt.legend()
plt.show()

# %% [markdown]
# > We can see by the above graph that in Europe, **Shooter** surpasses **Action** games as the most popular genre, unlike the global situation.
# <br>

# %% [markdown]
# ### **_Japan Sales in each Genre_**

# %%
genre_jpsales = data.groupby("Genre").sum()['Japan'].to_frame()
genre_jpsales.reset_index(inplace=True)
genre_jpsales
# Out:
#                Genre  Japan
# 0             Action  10.27
# 1   Action-Adventure   1.96
# 2          Adventure   1.64
# 3           Fighting   1.67
# 4                MMO   0.20
# 5               Misc   0.96
# 6              Music   0.17
# 7              Party   0.00
# 8           Platform   0.67
# 9             Puzzle   0.00
# 10            Racing   0.76
# 11      Role-Playing   9.42
# 12           Shooter   4.42
# 13        Simulation   0.28
# 14            Sports   1.83
# 15          Strategy   0.34
# 16      Visual Novel   0.19

# %%
genre = genre_jpsales['Genre']
jp_sales = genre_jpsales['Japan']

# %% [markdown]
# **_Line Plot over Bar Plot_**

# %%
plt.figure(figsize=(14, 8))

jp_sales.plot(color='purple', grid=True, label='Japan Sales', linewidth=3)
sns.barplot(genre, jp_sales, alpha=0.8, edgecolor='black').set_xticklabels(genre, rotation=75, horizontalalignment='right')

plt.title("Japan Sales in each Genre (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.ylabel("Japan Sales", fontdict = {'fontsize': 15}, labelpad=20)
plt.xlabel("Genre", fontdict = {'fontsize': 15})
plt.legend()
plt.show()

# %% [markdown]
# > We can see by the above graph that in Japan, **Action** genre is the most popular.<br>
# >But surprisingly, it is followed by **Role-Playing** at the 2nd position rather than **Shooter** games.
# <br>

# %% [markdown]
# ### **_Top 10 Highest Grossing Games by Global Sales_**

# %%
high_gross = data.copy()
high_gross.reset_index(inplace=True)
high_gross.head(10)
# Out:
#                              Game    Year             Genre  \
# 0              Grand Theft Auto V  2014.0            Action
# 1       Call of Duty: Black Ops 3  2015.0           Shooter
# 2           Red Dead Redemption 2  2018.0  Action-Adventure
# 3              Call of Duty: WWII  2017.0           Shooter
# 4                         FIFA 18  2017.0            Sports
# 5                         FIFA 17  2016.0            Sports
# 6                 Uncharted (PS4)  2016.0            Action
# 7                Spider-Man (PS4)  2018.0  Action-Adventure
# 8  Call of Duty: Infinite Warfare  2016.0           Shooter
# 9                       Fallout 4  2015.0      Role-Playing
#
#                         Publisher  North America  Europe  Japan  \
# 0                  Rockstar Games           6.06    9.71   0.60
# 1                      Activision           6.18    6.05   0.41
# 2                  Rockstar Games           5.26    6.21   0.21
# ...

# %% [markdown]
# >**<font color="teal">Reason for taking the original dataframe and not the cleaned one</font>**<br><br>
# > We are analysing in the original dataframe instead of the cleaned dataframe, as in this particular plot, there will not be any difference if `Year` or `Publisher` has a _null_ value or not.

# %%
gross_games = high_gross.head(10)['Game']
gross_sales = high_gross.head(10)['Global']

# %% [markdown]
# **_Horizontal Bar Plot_**

# %%
plt.figure(figsize=(10, 6))

bars = plt.barh(gross_games, gross_sales, color=['red', 'orange', 'orange', 'orange', 'green', 'green', 'lightgreen', 'lightgreen', 'cyan', 'cyan'], edgecolor='black')
plt.title("Top 10 \"Highest Grossing Games\" by their Global Sales (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.gca().invert_yaxis()

plt.xlabel("Global Sales", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Games", fontdict = {'fontsize': 15}, labelpad=15)

plt.grid(linestyle='--', axis='x', alpha=0.3)
plt.plot()
# Out:
# []

# %% [markdown]
# > We can see by the above graph that Rockstar Studio's **Grand Theft Auto V** or popularly known as **GTA V** is the highest grossing game of all games till now.<br><br>
# >It is followed by Activision's **Call of Duty: Black Ops 3**.
# <br>

# %% [markdown]
# ### **_Top 10 Highest Grossing Games by North America Sales_**

# %%
high_gross_na = high_gross.sort_values('North America', ascending=False)
high_gross_na.head(10)
# Out:
#                               Game    Year             Genre  \
# 1        Call of Duty: Black Ops 3  2015.0           Shooter
# 0               Grand Theft Auto V  2014.0            Action
# 2            Red Dead Redemption 2  2018.0  Action-Adventure
# 3               Call of Duty: WWII  2017.0           Shooter
# 6                  Uncharted (PS4)  2016.0            Action
# 7                 Spider-Man (PS4)  2018.0  Action-Adventure
# 11      Star Wars Battlefront 2015  2015.0           Shooter
# 8   Call of Duty: Infinite Warfare  2016.0           Shooter
# 9                        Fallout 4  2015.0      Role-Playing
# 12  Call of Duty: Advanced Warfare  2014.0           Shooter
#
#                          Publisher  North America  Europe  Japan  \
# 1                       Activision           6.18    6.05   0.41
# 0                   Rockstar Games           6.06    9.71   0.60
# 2                   Rockstar Games           5.26    6.21   0.21
# ...

# %% [markdown]
# > Created a new dataframe in which the original dataframe is sorted by the **North America** sales.
# <br>

# %%
gross_games_na = high_gross_na.head(10)['Game']
gross_sales_na = high_gross_na.head(10)['North America']

# %% [markdown]
# **_Horizontal Bar Plot_**

# %%
plt.figure(figsize=(10, 6))

bars = plt.barh(gross_games_na, gross_sales_na, color=['red', 'red', 'orange', 'green', 'green', 'teal', 'lightgreen', 'lightgreen', 'cyan', 'cyan'], edgecolor='black')
plt.title("Top 10 \"Highest Grossing Games\" by their North America Sales (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.gca().invert_yaxis()

plt.xlabel("North America Sales", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Games", fontdict = {'fontsize': 15}, labelpad=15)

plt.grid(linestyle='--', axis='x', alpha=0.3)
plt.plot()
# Out:
# []

# %% [markdown]
# > We can see by the above graph that Activision's **Call of Duty: Black Ops 3** is the highest grossing game of all games till now in **_North America_**.<br><br>
# >The most grossing game in the world, **GTA V**, is insignificantly short to be at the first spot in **_North America_**.
# <br>

# %% [markdown]
# ### **_Publishers and their shares in Top 10 Highest Grossing Games_**

# %%
publishers_gross = high_gross.head(10).groupby('Publisher').count().sort_values('Game', ascending=False)['Game'].to_frame()
publishers_gross.reset_index(inplace=True)
publishers_gross
# Out:
#                         Publisher  Game
# 0                      Activision     3
# 1                  Rockstar Games     2
# 2  Sony Interactive Entertainment     2
# 3              Bethesda Softworks     1
# 4                       EA Sports     1
# 5                 Electronic Arts     1

# %% [markdown]
# >Created a dataset with attributes- _publishers_ and their _number of games in top 10 highest grossing games_.

# %%
publisher_name = publishers_gross['Publisher']
number_games = publishers_gross['Game']

# %% [markdown]
# **_Pie Chart_**

# %%
fig1, ax1 = plt.subplots(figsize=(15,7))

explode = (0.1, 0.15, 0.1, 0.2, 0.1, 0.15)
ax1.pie(number_games, explode=explode, labels=publisher_name, autopct='%1.0f%%', shadow=True, startangle=90)
ax1.axis('equal')
fig1.suptitle("Publishers with their share in \"Top 10 Highest Grossing Games\"", fontsize=25, fontdict = {'color': 'blue'})

plt.plot()
# Out:
# []

# %% [markdown]
# > We can see by the above graph that **Activision** has the highest share in _Top 10 Highest Grossing Games_.<br><br>
# > Followed by **Rockstar Games** and **Sony Interactive Entertainment**.
# <br>

# %% [markdown]
# ### **_Publishers and their shares in Top 50 Highest Grossing Games_**

# %%
publishers_gross_top = high_gross.head(50).groupby('Publisher').count().sort_values('Game', ascending=False)['Game'].to_frame()
publishers_gross_top.reset_index(inplace=True)
publishers_gross_top
# Out:
#                                  Publisher  Game
# 0                                  Ubisoft     9
# 1                               Activision     8
# 2                                EA Sports     6
# 3                          Electronic Arts     5
# 4           Sony Interactive Entertainment     5
# 5                                2K Sports     3
# 6              Sony Computer Entertainment     3
# 7                       Bethesda Softworks     2
# 8                                   Capcom     2
# 9                           Rockstar Games     2
# 10                  Blizzard Entertainment     1
# 11                      Namco Bandai Games     1
# 12                             Square Enix     1
# 13                Warner Bros. Interactive     1
# 14  Warner Bros. Interactive Entertainment     1

# %% [markdown]
# >Created a dataset with attributes- _publishers_ and their _number of games in top 50 highest grossing games_.

# %%
publisher_name_top = publishers_gross_top['Publisher']
number_games_top = publishers_gross_top['Game']

# %% [markdown]
# **_Pie Chart_**

# %%
fig1, ax1 = plt.subplots(figsize=(15,7))

explode = (0.2, 0.15, 0.1, 0.5, 0.1, 0.15, 0.1, 0.2, 0.1, 0.15, 0.1, 0.5, 0.15, 0.1, 0.5)
ax1.pie(number_games_top, explode=explode, labels=publisher_name_top, autopct='%1.0f%%', shadow=True, startangle=25)
ax1.axis('equal')
fig1.suptitle("Publishers with their share in \"Top 50 Highest Grossing Games\"", fontsize=25, fontdict = {'color': 'blue'})

plt.plot()
# Out:
# []

# %% [markdown]
# > We can see by the above graph that **Ubisoft** has the highest share in _Top 50 Highest Grossing Games_.<br><br>
# > Followed by **Activision** and **EA Sports**, the former having the highest share in _Top 10 Highest Grossing Games_.
# <br>

# %% [markdown]
# ### **_ScatterPlot of Global Sales for All Games_**

# %%
plt.figure(figsize=(13, 8))

plt.title("ScatterPlot of Global Sales for All Games (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})

plt.xlabel("Years", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Global Sales", fontdict = {'fontsize': 15}, labelpad=20)

plt.scatter(dataWOna['Year'], dataWOna['Global'], color='red')

# %% [markdown]
# > We can see by the above graph that every year, **majority of games have sales in between 0.0 and 5.0 million copies**.<br><br>
# > Also, the **game having highest global sales was published in 2014**.
# <br>

# %% [markdown]
# ### **_ScatterPlot of North America Sales for All Games_**

# %%
plt.figure(figsize=(13, 8))

plt.title("ScatterPlot of North America Sales for All Games (2013-2020)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})

plt.xlabel("Years", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("North America Sales", fontdict = {'fontsize': 15}, labelpad=20)

plt.scatter(dataWOna['Year'], dataWOna['North America'], color='red')

# %% [markdown]
# > We can see by the above graph that every year, **majority of games have sales in between 0 and 2 million copies**.<br><br>
# > Also, the **game having highest North America sales was published in 2015**.
# <br>

# %% [markdown]
# ### **_Sales comparision of Ubisoft games for all Regions each Year_**

# %%
sales_data_ubi = dataWOna[dataWOna['Publisher']=='Ubisoft']

sales_data_ubi = sales_data_ubi.groupby('Year').sum()
sales_data_ubi = sales_data_ubi[sales_data_ubi['Global']!=0.00]
sales_data_ubi.reset_index(inplace=True)
sales_data_ubi
# Out:
#      Year  North America  Europe  Japan  Rest of World  Global
# 0  2013.0           1.28    1.73   0.06           0.59    3.66
# 1  2014.0           5.21    9.07   0.39           2.72   17.39
# 2  2015.0           2.45    4.40   0.44           1.31    8.62
# 3  2016.0           3.95    7.15   0.42           2.12   13.66
# 4  2017.0           3.95    4.96   0.40           1.74   11.06
# 5  2018.0           1.66    2.15   0.20           0.74    4.77

# %% [markdown]
# > This is the dataframe for all _Ubisoft_ Games published each year.

# %%
na_sales = sales_data_ubi['North America']
eu_sales = sales_data_ubi['Europe']
jp_sales = sales_data_ubi['Japan']
rst_sales = sales_data_ubi['Rest of World']
glb_sales = sales_data_ubi['Global']

years = sales_data_ubi['Year']

# %% [markdown]
# **_Multiple Line Plots_**

# %%
plt.figure(figsize=(14, 8))

plt.plot(years, na_sales, color='orange', linewidth=2, label='North America')
plt.plot(years, eu_sales, color='blue', linewidth=2, label='Europe')
plt.plot(years, jp_sales, color='green', linewidth=2, label='Japan')
plt.plot(years, rst_sales, color='violet', linewidth=2, label='Rest of World')
plt.plot(years, glb_sales, color='black', linewidth=2, label='Global')


plt.title("Region based Sales comparision each Year for Ubisoft (2013-2018)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.xlabel("Years", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Sales", fontdict = {'fontsize': 15}, labelpad=20)
plt.legend()
plt.xticks(years)
plt.show()

# %% [markdown]
# > We can see by the above graph that for **_Ubisoft_**, Sales in **Europe** are always higher than other regions.<br><br>
# >Also, **Japan** has very insignificant Sales for **_Ubisoft_** compared to other regions.
# <br>

# %% [markdown]
# ### **_Sales comparision of Namco Bandai Games for all Regions each Year_**

# %%
sales_data_nbg = dataWOna[dataWOna['Publisher']=='Namco Bandai Games']

sales_data_nbg = sales_data_nbg.groupby('Year').sum()
sales_data_nbg = sales_data_nbg[sales_data_nbg['Global']!=0.00]
sales_data_nbg.reset_index(inplace=True)
sales_data_nbg
# Out:
#      Year  North America  Europe  Japan  Rest of World  Global
# 0  2014.0           0.11    0.03   0.03           0.03    0.20
# 1  2015.0           2.67    4.59   1.05           1.38    9.71
# 2  2016.0           2.91    2.26   1.80           1.06    8.04
# 3  2017.0           1.39    1.40   0.93           0.56    4.28
# 4  2018.0           1.05    0.85   0.37           0.39    2.64

# %% [markdown]
# > This is the dataframe for all _Namco Bandai Games_ published each year.

# %%
na_sales = sales_data_nbg['North America']
eu_sales = sales_data_nbg['Europe']
jp_sales = sales_data_nbg['Japan']
rst_sales = sales_data_nbg['Rest of World']
glb_sales = sales_data_nbg['Global']

years = sales_data_nbg['Year']

# %% [markdown]
# **_Multiple Line Plots_**

# %%
plt.figure(figsize=(14, 8))

plt.plot(years, na_sales, color='orange', linewidth=2, label='North America')
plt.plot(years, eu_sales, color='blue', linewidth=2, label='Europe')
plt.plot(years, jp_sales, color='green', linewidth=2, label='Japan')
plt.plot(years, rst_sales, color='violet', linewidth=2, label='Rest of World')
plt.plot(years, glb_sales, color='black', linewidth=2, label='Global')


plt.title("Region based Sales comparision each Year for Namco Bandai Games (2014-2018)", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.xlabel("Years", fontdict = {'fontsize': 15})
plt.ylabel("Sales", fontdict = {'fontsize': 15})
plt.legend()
plt.xticks(years)
plt.show()

# %% [markdown]
# > We can see by the above graph that for **_Namco Bandai Games_**, Sales in **Europe** were higher till **2016** and then **North America** overtook the throne.<br><br>
# >Surprisingly, **Japan** has much significant Sales for **_Namco Bandai Games_** compared to **_Ubisoft_**.
# <br>

# %% [markdown]
# ### **_Region Sales VS Global Sales for Sony Interactive Entertainment_**

# %%
data_sony = dataWOna[dataWOna['Publisher']=='Sony Interactive Entertainment']
data_sony.head(7)
# Out:
#                           Game    Year             Genre  \
# 6              Uncharted (PS4)  2016.0            Action
# 7             Spider-Man (PS4)  2018.0  Action-Adventure
# 17            God of War (PS4)  2018.0            Action
# 18          Horizon: Zero Dawn  2017.0            Action
# 39          Gran Turismo Sport  2017.0            Racing
# 66      Ratchet & Clank (2016)  2016.0          Platform
# 68  Uncharted: The Lost Legacy  2017.0            Action
#
#                          Publisher  North America  Europe  Japan  \
# 6   Sony Interactive Entertainment           4.49    3.93   0.21
# 7   Sony Interactive Entertainment           3.64    3.39   0.32
# 17  Sony Interactive Entertainment           2.83    2.17   0.13
# 18  Sony Interactive Entertainment           2.20    2.43   0.28
# 39  Sony Interactive Entertainment           0.63    2.35   0.24
# 66  Sony Interactive Entertainment           0.97    0.97   0.06
# ...

# %% [markdown]
# >This dataset consists of all _Sony Interactive Entertainment_ games data.

# %% [markdown]
# **_Multiple Line Plots_**

# %%
plt.figure(figsize=(14, 7))

plt.plot(data_sony['Global'], data_sony['North America'], label = 'North America')
plt.plot(data_sony['Global'], data_sony['Europe'], label = 'Europe')
plt.plot(data_sony['Global'], data_sony['Japan'], label = 'Japan')
plt.plot(data_sony['Global'], data_sony['Rest of World'], label = 'Rest of World')

plt.title("Region Sales VS Global Sales for Sony Interactive Entertainment", y=1.05, fontdict = {'fontsize': 25, 'color': 'blue'})
plt.xlabel("Global Sales", fontdict = {'fontsize': 15}, labelpad=20)
plt.ylabel("Region Sales", fontdict = {'fontsize': 15}, labelpad=30)
plt.xticks(np.arange(min(data_sony['Global']), max(data_sony['Global'])+1, 0.5))
plt.yticks(np.arange(0, 4+1, 0.5))

plt.grid(linestyle='-.', alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# > We can see by the above graph that when the **Global Sales** are extrememly small, the contributions from all regions is almost equal.<br><br>
# > Further, when the **Global Sales** increase, **Europe** has the highest contributions than other regions.<br>
# > Which is again proved wrong, when **North America** overtakes **Europe** Sales after almost **5.8 million Global Sales**.<br><br>
# > But **Japan** has always the least contribution than all the other regions.
# <br>
